# %% [markdown]
# ### Part1 :
# ### Prepare input data for diagnosis portion

# %%
import pandas as pd
import spacy
import random
import re
# Out:
# 2023-06-07 07:23:17.130066: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-07 07:23:17.322333: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-06-07 07:23:17.322361: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-06-07 07:23:17.966348: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-06-07 07:23:17.966400: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-06-07 07:23:17.966406: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2023-06-07 07:23:18.750757: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2023-06-07 07:23:18.750781: W tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:265] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-06-07 07:23:18.750797: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (ihsan-HP-Pavilion-Gaming-Laptop): /proc/driver/nvidia/version does not exist

# %%
nlp = spacy.load('en_core_web_md')

# %%
def get_sentence_vectors(text, nlp):
    
    # get tokens for each word in a sentence
    embedding = nlp(text).vector.tolist()
    
    return embedding

# %% [markdown]
# Import and merge data

# %%
illness_df = pd.read_csv('/home/ihsan/Documents/GitHub/Rasa/Rasa-Chatbot/diaganosis symtom/dia_t.csv')
symptom_df = pd.read_csv('/home/ihsan/Documents/GitHub/Rasa/Rasa-Chatbot/diaganosis symtom/sym_t.csv')
links_df = pd.read_csv('/home/ihsan/Documents/GitHub/Rasa/Rasa-Chatbot/diaganosis symtom/diffsydiw.csv')

# %%
illness_df.head()
# Out:
#    did                                           diagnose
# 0    1  Abdominal aortic aneurysm
# (enlarged major bloo...
# 1    2                                 Abdominal swelling
# 2    3                                   Abdominal trauma
# 3    4                               Abrasions
#  (scrapes)
# 4    5  ACE inhibitor induced cough
# blood pressure med...

# %%
symptom_df.head()
# Out:
#    syd                      symptom
# 0    1         Upper abdominal pain
# 1    2         Lower abdominal pain
# 2    3  Abscess (Collection of pus)
# 3    4                Alcohol abuse
# 4    5        Anxiety (Nervousness)

# %%
source_data = (links_df
               .merge(illness_df, on="did")
               .merge(symptom_df, on="syd"))
source_data
# Out:
#         syd     did  wei                                           diagnose
# 0       1.0   163.0  2.0      Cholecystitis
# inflammation of the gallbladder  \
# 1       1.0   164.0  2.0             Choledocholithiasis
# stone in bile duct
# 2       1.0   165.0  1.0                          Cholelithiasis
# gallstones
# 3       1.0   187.0  2.0                                       Constipation
# 4       1.0   306.0  2.0                        Gastric ulcer
# stomach ulcer
# ...     ...     ...  ...                                                ...
# 5563  106.0   827.0  0.0  Vulvar squamous cell carcinoma
# skin cancer on ...
# 5564  186.0   966.0  2.0                                 Hair loss
# alopecia
# 5565  186.0  1415.0  0.0                                 Hypoparathyroidism
# 5566  186.0  1415.0  0.0                                 Hypoparathyroidism
# 5567  186.0  1245.0  1.0  Male pattern hair loss
# hereditary-patterned ba...
#
#                                symptom
# 0                 Upper abdominal pain
# 1                 Upper abdominal pain
# 2                 Upper abdominal pain
# 3                 Upper abdominal pain
# 4                 Upper abdominal pain
# ...                                ...
# 5563  Vaginal bleeding after menopause
# 5564              Hair loss (Baldness)
# 5565              Hair loss (Baldness)
# 5566              Hair loss (Baldness)
# 5567              Hair loss (Baldness)
#
# [5568 rows x 5 columns]

# %%
source_data
# Out:
#         syd     did  wei                                           diagnose
# 0       1.0   163.0  2.0      Cholecystitis
# inflammation of the gallbladder  \
# 1       1.0   164.0  2.0             Choledocholithiasis
# stone in bile duct
# 2       1.0   165.0  1.0                          Cholelithiasis
# gallstones
# 3       1.0   187.0  2.0                                       Constipation
# 4       1.0   306.0  2.0                        Gastric ulcer
# stomach ulcer
# ...     ...     ...  ...                                                ...
# 5563  106.0   827.0  0.0  Vulvar squamous cell carcinoma
# skin cancer on ...
# 5564  186.0   966.0  2.0                                 Hair loss
# alopecia
# 5565  186.0  1415.0  0.0                                 Hypoparathyroidism
# 5566  186.0  1415.0  0.0                                 Hypoparathyroidism
# 5567  186.0  1245.0  1.0  Male pattern hair loss
# hereditary-patterned ba...
#
#                                symptom
# 0                 Upper abdominal pain
# 1                 Upper abdominal pain
# 2                 Upper abdominal pain
# 3                 Upper abdominal pain
# 4                 Upper abdominal pain
# ...                                ...
# 5563  Vaginal bleeding after menopause
# 5564              Hair loss (Baldness)
# 5565              Hair loss (Baldness)
# 5566              Hair loss (Baldness)
# 5567              Hair loss (Baldness)
#
# [5568 rows x 5 columns]

# %%
# Remove missing data and select columns we needed

source_data = source_data.loc[~(source_data['symptom'].isna()) & ~(source_data['diagnose'].isna()),['did', 'syd', 'diagnose', 'symptom']]

source_data.columns = ['illness_id', 'symptom_id', 'illness', 'symptom']

# %%
source_data
# Out:
#       illness_id  symptom_id
# 0          163.0         1.0  \
# 1          164.0         1.0
# 2          165.0         1.0
# 3          187.0         1.0
# 4          306.0         1.0
# ...          ...         ...
# 5563       827.0       106.0
# 5564       966.0       186.0
# 5565      1415.0       186.0
# 5566      1415.0       186.0
# 5567      1245.0       186.0
#
#                                                 illness
# 0         Cholecystitis
# inflammation of the gallbladder  \
# 1                Choledocholithiasis
# stone in bile duct
# 2                             Cholelithiasis
# gallstones
# 3                                          Constipation
# 4                           Gastric ulcer
# stomach ulcer
# ...                                                 ...
# 5563  Vulvar squamous cell carcinoma
# skin cancer on ...
# 5564                                 Hair loss
# alopecia
# 5565                                 Hypoparathyroidism
# 5566                                 Hypoparathyroidism
# 5567  Male pattern hair loss
# hereditary-patterned ba...
#
#                                symptom
# 0                 Upper abdominal pain
# 1                 Upper abdominal pain
# 2                 Upper abdominal pain
# 3                 Upper abdominal pain
# 4                 Upper abdominal pain
# ...                                ...
# 5563  Vaginal bleeding after menopause
# 5564              Hair loss (Baldness)
# 5565              Hair loss (Baldness)
# 5566              Hair loss (Baldness)
# 5567              Hair loss (Baldness)
#
# [5204 rows x 4 columns]

# %%
# tidy up some new messy characters
source_data['illness'] = source_data['illness'].str.replace('\x0b', ' ')
source_data['symptom'] = source_data['symptom'].str.replace('\x0b', ' ')

# %%
source_data
# Out:
#       illness_id  symptom_id
# 0          163.0         1.0  \
# 1          164.0         1.0
# 2          165.0         1.0
# 3          187.0         1.0
# 4          306.0         1.0
# ...          ...         ...
# 5563       827.0       106.0
# 5564       966.0       186.0
# 5565      1415.0       186.0
# 5566      1415.0       186.0
# 5567      1245.0       186.0
#
#                                                 illness
# 0         Cholecystitis inflammation of the gallbladder  \
# 1                Choledocholithiasis stone in bile duct
# 2                             Cholelithiasis gallstones
# 3                                          Constipation
# 4                           Gastric ulcer stomach ulcer
# ...                                                 ...
# 5563  Vulvar squamous cell carcinoma skin cancer on ...
# 5564                                 Hair loss alopecia
# 5565                                 Hypoparathyroidism
# 5566                                 Hypoparathyroidism
# 5567  Male pattern hair loss hereditary-patterned ba...
#
#                                symptom
# 0                 Upper abdominal pain
# 1                 Upper abdominal pain
# 2                 Upper abdominal pain
# 3                 Upper abdominal pain
# 4                 Upper abdominal pain
# ...                                ...
# 5563  Vaginal bleeding after menopause
# 5564              Hair loss (Baldness)
# 5565              Hair loss (Baldness)
# 5566              Hair loss (Baldness)
# 5567              Hair loss (Baldness)
#
# [5204 rows x 4 columns]

# %% [markdown]
# Use our function to convert each symptom to a vector representation we can then save our symptom data down to the data folder

# %%
symptom_df = symptom_df.loc[~symptom_df['symptom'].isna()]

symptom_df['embedding'] = symptom_df.apply(lambda row: get_sentence_vectors(row['symptom'], nlp), axis=1)
symptom_df.columns = ['symptom_id', 'symptom', 'symptom_vector']

# %%
symptom_df
# Out:
#      symptom_id                          symptom
# 0             1             Upper abdominal pain  \
# 1             2             Lower abdominal pain
# 2             3      Abscess (Collection of pus)
# 3             4                    Alcohol abuse
# 4             5            Anxiety (Nervousness)
# ..          ...                              ...
# 267         295                 Nipple discharge
# 268         301  Shoulder stiffness or tightness
# 269         303       Arm stiffness or tightness
# 270         304              High blood pressure
# 271         306                 High blood sugar
#
#                                         symptom_vector
# 0    [-0.3931533396244049, -1.122189998626709, -2.3...
# 1    [0.11224666982889175, -1.3984565734863281, -2....
# 2    [-4.394866943359375, -5.325353145599365, 3.294...
# 3    [-1.0100150108337402, -3.2876999378204346, -1....
# 4    [-2.1256749629974365, -4.137800216674805, 4.55...
# ..                                                 ...
# 267  [-1.7614949941635132, 0.5206300020217896, -1.9...
# 268  [-1.2457798719406128, 2.181957483291626, -6.26...
# 269  [-1.7361524105072021, 1.2958674430847168, -4.8...
# 270  [-0.959559977054596, 0.45383667945861816, -2.6...
# 271  [-0.032566625624895096, -1.4907633066177368, -...
#
# [246 rows x 3 columns]

# %%
# remove messy charecters

symptom_df['symptom'] = symptom_df['symptom'].str.replace('\x0b', ' ')

# %%
source_data.to_pickle('input_data/source_data.pkl')
symptom_df.to_pickle('input_data/symptoms.pkl')

# %% [markdown]
# ### Create a vector of symtpoms for each illness described in the data

# %% [markdown]
# Here we will loop through each illness described in the dataset
# and flag (with a 1 or 0) each of the symptoms of that illness.
# We will do then compare a list of flagged symptoms described by
# the user to this using a cosine similarity function to diagnose
# a potential illness.

# %%
# list of illness 
illnesses = list(source_data['illness'].drop_duplicates())

# list we will use store our illness vectors 
symptom_vectors = []

for illness in illnesses:
    
    illnesses_symptoms = list(source_data.loc[source_data['illness'] == illness, 'symptom'].drop_duplicates())
    
    symptom_df['related_to_illness'] = 0
    symptom_df.loc[symptom_df['symptom'].isin(illnesses_symptoms), "related_to_illness"] = 1
    
    symptom_vectors.append(list(symptom_df["related_to_illness"]))
    
diagnosis_data = pd.DataFrame({"illness":illnesses,
                                "illness_vector":symptom_vectors})

# %% [markdown]
# ### Part 2:
# ### Generate training samples with flagged entities

# %% [markdown]
# In this part we will attempt to generate some training examples for the NLU model to understand how our users will describe symtoms to the chat bot. To do this we simply loop through our symptoms, sometimes combining them before appending them to different beginnings/endings.
#
# We also make sure to tag any symptom describtions as a symptom entity, which will be understood by Rasa's NLU model. You can see this is accomplished by inserting '(symptom)' beside any mention of symptoms.
#
# The output of this is inserted into nlu.md within the main project.

# %%
number_of_symtoms = [1, 2, 3, 4]
start_of_description = [
    "I have",
    "I'm suffering from",
    "I have really bad",
    "My symptoms are",
    "For the last few days I have had",
    "My husband is suffering from" ,
    "My wife is suffering from",
    "My son is suffering from",
    "My daughter is suffering from",
    "My child is suffering from",
    "I don't feel well, I have"
]

# Get some examples of users describing different number of symtoms 

for symptoms_count in number_of_symtoms:
    
    # make 100 example of each number of symtoms 
    for ex in range(1, 101):
        
        description_beginning = random.choice(start_of_description)
        
        # collect some random symtoms 
        symptom_1 = symptom_df['symptom'].sample(1).iloc[0].lower()
        symptom_2 = symptom_df['symptom'].sample(1).iloc[0].lower()
        symptom_3 = symptom_df['symptom'].sample(1).iloc[0].lower()
        symptom_4 = symptom_df['symptom'].sample(1).iloc[0].lower()
        
        symptoms = [symptom_1, symptom_2, symptom_3, symptom_4]
        symptom_entity = []
        
        # Remove paranthases from symptoms and add nessecary entity tags to symtoms 
        for symptom in symptoms:
            symptom = re.sub(r"\([^)]+\)", "", symptom).strip()
            symptom = f"[{symptom}](symptom)"
            symptom_entity.append(symptom)
            
        symptom_1 = symptom_entity[0]
        symptom_2 = symptom_entity[1]
        symptom_3 = symptom_entity[2]
        symptom_4 = symptom_entity[3]
        
        # Create the training sample strig 
        
        if symptoms_count == 1:
            
            symptom_string = f"- {description_beginning} {symptom_1}"
            
        if symptoms_count == 2:
            
            symptom_string = f"- {description_beginning} {symptom_1} and {symptom_2}"
            
        if symptoms_count == 3:
            
            symptom_string = f"- {description_beginning} {symptom_1}, {symptom_2}, and {symptom_3}"
            
        if symptoms_count == 4:
            
            symptom_string = f"- {description_beginning} {symptom_1}, {symptom_2}, {symptom_3}, {symptom_4}"
        
        print(symptom_string)
# Out:
# - My symptoms are [ringing in ears](symptom)
# - I have really bad [lump or mass of breast](symptom)
# - I'm suffering from [chest pressure](symptom)
# - My child is suffering from [suicidal tendencies](symptom)
# - My symptoms are [congestion in chest or lungs](symptom)
# - My son is suffering from [foot redness](symptom)
# - My husband is suffering from [substance abuse](symptom)
# - My son is suffering from [arm stiffness or tightness](symptom)
# - My son is suffering from [painful urination](symptom)
# - I have really bad [diarrhea](symptom)
# - For the last few days I have had [sinus pain and pressure](symptom)
# - For the last few days I have had [constipation](symptom)
# - My child is suffering from [mouth ulcers](symptom)
# - For the last few days I have had [arm numbness](symptom)
# - I'm suffering from [arm numbness](symptom)
# - I have [seizure](symptom)
# - I don't feel well, I have [eye floaters](symptom)
# - My symptoms are [hand redness](symptom)
# - My son is suffering from [shoulder stiffness or tightness](symptom)
# - My daughter is suffering from [low heart rate](symptom)
# - I'm suffering from [congestion in chest or lungs](symptom)
# - I have really bad [urinary retention](symptom)
# - I'm suffering from [face numbness](symptom)
# - For the last few days I have had [arm ache or pain](symptom)
# - My son is suffering from [vaginal itching](symptom)
# - For the last few days I have had [fever in the returning traveler](symptom)
# - My daughter is suffering from [stings](symptom)
# - My husband is suffering from [ringing in ears](symptom)
# - I have really bad [blister](symptom)
# - My husband is suffering from [skin infection](symptom)
# - For the last few days I have had [vaginal itching](symptom)
# - My wife is suffering from [vaginal itching](symptom)
# - My daughter is suffering from [rash](symptom)
# - My child is suffering from [pelvic pain](symptom)
# - My son is suffering from [dry skin](symptom)
# - My daughter is suffering from [difficulty breathing](symptom)
# - My symptoms are [laceration](symptom)
# - I'm suffering from [painful rash](symptom)
# - I don't feel well, I have [hair loss](symptom)
# - I'm suffering from [arm numbness](symptom)
# - I have [back ache or pain](symptom)
# - My son is suffering from [drooling](symptom)
# - My son is suffering from [hot flashes](symptom)
# - My wife is suffering from [low blood sugar](symptom)
# - I'm suffering from [leg cut](symptom)
# - I have really bad [lip swelling](symptom)
# - My wife is suffering from [vertigo](symptom)
# - For the last few days I have had [snake bite](symptom)
# - My wife is suffering from [eye swelling](symptom)
# - I'm suffering from [blood in vomit](symptom)
# - My wife is suffering from [cranky, crying, fussy, irritable child](symptom)
# - My child is suffering from [eye pain](symptom)
# - I'm suffering from [fever](symptom)
# - I have really bad [poisoning](symptom)
# - I'm suffering from [ear pressure](symptom)
# - I'm suffering from [vaginal discharge](symptom)
# - I have really bad [arm itching](symptom)
# - I have [hot flashes](symptom)
# - My child is suffering from [night sweats](symptom)
# - My husband is suffering from [psychiatric problem](symptom)
# - My husband is suffering from [penile discharge](symptom)
# - For the last few days I have had [skin growths](symptom)
# - My husband is suffering from [blurry vision](symptom)
# - My child is suffering from [leg numbness](symptom)
# - I have really bad [wrist pain](symptom)
# - My child is suffering from [pulling at ears](symptom)
# - My wife is suffering from [drooling](symptom)
# - My child is suffering from [laceration](symptom)
# - My child is suffering from [foot numbness](symptom)
# - My husband is suffering from [hand cut](symptom)
# - My son is suffering from [lump or mass of breast](symptom)
# - My son is suffering from [dry skin](symptom)
# - My symptoms are [bleeding in brain](symptom)
# - For the last few days I have had [fever of unknown origin](symptom)
# - My wife is suffering from [heart pulsations and palpitations](symptom)
# - My husband is suffering from [dementia](symptom)
# - My symptoms are [headache](symptom)
# - My daughter is suffering from [leg redness](symptom)
# - My husband is suffering from [leg ache or pain](symptom)
# - My daughter is suffering from [blood in urine](symptom)
# - I have [ear swelling](symptom)
# - For the last few days I have had [congestion in chest or lungs](symptom)
# - I don't feel well, I have [neck stiffness or tightness](symptom)
# - I don't feel well, I have [arm swelling](symptom)
# - My child is suffering from [overdose](symptom)
# - My wife is suffering from [muscle pain](symptom)
# - For the last few days I have had [hand, finger ache or pain](symptom)
# - My daughter is suffering from [skin growths](symptom)
# - For the last few days I have had [skin growths](symptom)
# - My son is suffering from [dementia](symptom)
# - I don't feel well, I have [arm redness](symptom)
# - I don't feel well, I have [depressed](symptom)
# - My wife is suffering from [nasal bleeding](symptom)
# - I have [dementia](symptom)
# - My daughter is suffering from [heart pulsations and palpitations](symptom)
# - My son is suffering from [ear pressure](symptom)
# - For the last few days I have had [penis inflammation or swelling](symptom)
# - My son is suffering from [pelvic pain](symptom)
# - I have [scrotal swelling](symptom)
# - My husband is suffering from [change in behavior](symptom)
# - My husband is suffering from [chest pain](symptom) and [puncture wound](symptom)
# - I don't feel well, I have [leg itching](symptom) and [rash](symptom)
# - My symptoms are [hand numbness](symptom) and [swallowing problem](symptom)
# - For the last few days I have had [bleeding in brain](symptom) and [vaginal itching](symptom)
# - My wife is suffering from [elbow ache or pain](symptom) and [lethargy](symptom)
# - My wife is suffering from [eye redness](symptom) and [mouth pain](symptom)
# - For the last few days I have had [poisoning](symptom) and [neck stiffness or tightness](symptom)
# - I don't feel well, I have [hand itching](symptom) and [heart pulsations and palpitations](symptom)
# - My child is suffering from [foot cut](symptom) and [anxiety](symptom)
# - My child is suffering from [nausea](symptom) and [vaginal discharge](symptom)
# - I'm suffering from [loss of balance](symptom) and [eye floaters](symptom)
# - My symptoms are [anger](symptom) and [stomach and abdominal pain](symptom)
# - My child is suffering from [increased urination](symptom) and [vaginal bleeding after menopause](symptom)
# - My son is suffering from [skin growths](symptom) and [suicidal tendencies](symptom)
# - For the last few days I have had [upper leg pain](symptom) and [sleep disorders](symptom)
# - I'm suffering from [arm ache or pain](symptom) and [leg cut](symptom)
# - I have [nipple discharge](symptom) and [urinary retention](symptom)
# - I have [abdominal swelling](symptom) and [painful rash](symptom)
# - My wife is suffering from [vaginal bleeding](symptom) and [painful urination](symptom)
# - I have [swollen gums](symptom) and [anger](symptom)
# - I'm suffering from [weight loss, unexplained](symptom) and [learning difficulties](symptom)
# - I don't feel well, I have [psychiatric problem](symptom) and [scrotal pain](symptom)
# - I'm suffering from [itchy eyes](symptom) and [hemoptysis](symptom)
# - My wife is suffering from [nipple discharge](symptom) and [sinus pain and pressure](symptom)
# - My child is suffering from [facial droop](symptom) and [throat pain](symptom)
# - My wife is suffering from [agitated](symptom) and [vaginal bleeding during pregnancy](symptom)
# - I'm suffering from [visual flashing lights](symptom) and [unsteady gait](symptom)
# - I don't feel well, I have [hand cut](symptom) and [foot itching](symptom)
# - I have [traveler's diarrhea](symptom) and [upper abdominal pain](symptom)
# - For the last few days I have had [pain in the ear](symptom) and [hoarse voice](symptom)
# - I have [limping in a child](symptom) and [obesity](symptom)
# - My child is suffering from [loss of balance](symptom) and [spider bite](symptom)
# - My symptoms are [hot skin](symptom) and [joint pain](symptom)
# - I'm suffering from [failure to thrive](symptom) and [nausea](symptom)
# - My symptoms are [congestion in chest or lungs](symptom) and [vaginal bleeding](symptom)
# - My daughter is suffering from [vaginal bleeding after menopause](symptom) and [jaw pain](symptom)
# - My husband is suffering from [anger](symptom) and [low back ache or pain](symptom)
# - I have [abscess](symptom) and [low back ache or pain](symptom)
# - My wife is suffering from [arm cut](symptom) and [loss of balance](symptom)
# - I have really bad [psychiatric problem](symptom) and [pelvic pain](symptom)
# - My son is suffering from [traveler's diarrhea](symptom) and [calf swelling](symptom)
# - My symptoms are [snake bite](symptom) and [chest pain](symptom)
# - My husband is suffering from [fever of unknown origin](symptom) and [congestion in chest or lungs](symptom)
# - My wife is suffering from [bloody diarrhea](symptom) and [retaining fluid](symptom)
# - My child is suffering from [heel pain](symptom) and [joint pain](symptom)
# - My son is suffering from [swollen gums](symptom) and [foot redness](symptom)
# - My wife is suffering from [congestion in chest or lungs](symptom) and [pelvic pain](symptom)
# - For the last few days I have had [vaginal bleeding after menopause](symptom) and [kidney pain](symptom)
# - My symptoms are [anxiety](symptom) and [sweating](symptom)
# - My wife is suffering from [insomnia](symptom) and [arm redness](symptom)
# - My symptoms are [mouth swelling](symptom) and [high blood pressure](symptom)
# - My wife is suffering from [skin sores](symptom) and [snoring](symptom)
# - My wife is suffering from [leg numbness](symptom) and [swollen gums](symptom)
# - My husband is suffering from [stomach and abdominal pain](symptom) and [skin swelling](symptom)
# - My symptoms are [nail injury](symptom) and [double vision](symptom)
# - My wife is suffering from [hurts to breathe](symptom) and [bleeding gums](symptom)
# - I don't feel well, I have [back ache or pain](symptom) and [ear pressure](symptom)
# - My daughter is suffering from [nasal bleeding](symptom) and [headache](symptom)
# - My son is suffering from [elbow ache or pain](symptom) and [face numbness](symptom)
# - My symptoms are [bloody diarrhea](symptom) and [calf pain](symptom)
# - My symptoms are [increased thirst](symptom) and [skin infection](symptom)
# - My son is suffering from [vaginal bleeding](symptom) and [leg cut](symptom)
# - My child is suffering from [wheezing](symptom) and [rash](symptom)
# - My child is suffering from [bleeding in brain](symptom) and [chest pressure](symptom)
# - I'm suffering from [blood in vomit](symptom) and [double vision](symptom)
# - My husband is suffering from [chills](symptom) and [heat illness](symptom)
# - I have really bad [hoarse voice](symptom) and [ear pressure](symptom)
# - My son is suffering from [dementia](symptom) and [delusions or hallucinations](symptom)
# - My husband is suffering from [darkening of the skin](symptom) and [memory loss](symptom)
# - I'm suffering from [congestion in chest or lungs](symptom) and [memory loss](symptom)
# - My symptoms are [hot skin](symptom) and [nipple discharge](symptom)
# - I have really bad [swelling](symptom) and [foot cut](symptom)
# - My son is suffering from [upper leg pain](symptom) and [calf pain](symptom)
# - I'm suffering from [foot cut](symptom) and [hives](symptom)
# - I'm suffering from [incontinence](symptom) and [leg itching](symptom)
# - My son is suffering from [excessive appetite](symptom) and [flank pain](symptom)
# - My symptoms are [blister](symptom) and [blood in vomit](symptom)
# - My symptoms are [jaundice](symptom) and [trauma](symptom)
# - I'm suffering from [calf swelling](symptom) and [delusions or hallucinations](symptom)
# - I'm suffering from [heart pulsations and palpitations](symptom) and [leg redness](symptom)
# - I have really bad [leg cut](symptom) and [skin growths](symptom)
# - My wife is suffering from [vaginal pain](symptom) and [scrotal swelling](symptom)
# - I have really bad [mouth ulcers](symptom) and [muscle pain](symptom)
# - My daughter is suffering from [foot itching](symptom) and [leg itching](symptom)
# - My husband is suffering from [hand, finger ache or pain](symptom) and [mouth swelling](symptom)
# - I'm suffering from [loss of balance](symptom) and [shoulder stiffness or tightness](symptom)
# - I have [arm ache or pain](symptom) and [painful urination](symptom)
# - I don't feel well, I have [facial pain](symptom) and [fever of unknown origin](symptom)
# - For the last few days I have had [low blood sugar](symptom) and [arm numbness](symptom)
# - I don't feel well, I have [bleeding gums](symptom) and [arm stiffness or tightness](symptom)
# - My symptoms are [armpit pain](symptom) and [puncture wound](symptom)
# - My child is suffering from [learning difficulties](symptom) and [facial droop](symptom)
# - I don't feel well, I have [high blood sugar](symptom) and [throat pain](symptom)
# - My son is suffering from [pain in the ear](symptom) and [sinus pain and pressure](symptom)
# - My symptoms are [nausea](symptom) and [abdominal swelling](symptom)
# - My husband is suffering from [anger](symptom) and [skin growths](symptom)
# - I have really bad [cough](symptom) and [blood in vomit](symptom)
# - My child is suffering from [rash](symptom) and [confusion](symptom)
# - My wife is suffering from [joint stiffness](symptom) and [constipation](symptom)
# - I'm suffering from [wheezing](symptom) and [ear pressure](symptom)
# - My child is suffering from [increased facial hair](symptom), [memory loss](symptom), and [cough](symptom)
# - My husband is suffering from [unsteady gait](symptom), [skin swelling](symptom), and [toe pain](symptom)
# - I have really bad [liver failure](symptom), [heart murmur](symptom), and [swollen lymph nodes](symptom)
# - My wife is suffering from [hand itching](symptom), [skin swelling](symptom), and [arm cut](symptom)
# - I don't feel well, I have [vomiting](symptom), [tooth pain](symptom), and [sore throat](symptom)
# - My son is suffering from [difficulty breathing](symptom), [bloody diarrhea](symptom), and [agitated](symptom)
# - My symptoms are [leg redness](symptom), [head injury](symptom), and [double vision](symptom)
# - I have [chills](symptom), [hurts to breathe](symptom), and [lump or mass of breast](symptom)
# - My husband is suffering from [confusion](symptom), [scrotal pain](symptom), and [face numbness](symptom)
# - For the last few days I have had [dry skin](symptom), [snake bite](symptom), and [substance abuse](symptom)
# - I have really bad [blood in urine](symptom), [high blood pressure](symptom), and [penile discharge](symptom)
# - I have really bad [lethargy](symptom), [snake bite](symptom), and [flank pain](symptom)
# - My daughter is suffering from [shoulder ache or pain](symptom), [difficulty breathing](symptom), and [congestion in chest or lungs](symptom)
# - My symptoms are [learning difficulties](symptom), [depressed](symptom), and [vaginal bleeding after menopause](symptom)
# - I don't feel well, I have [alcohol abuse](symptom), [abscess](symptom), and [limping in a child](symptom)
# - My child is suffering from [eye redness](symptom), [face numbness](symptom), and [facial pain](symptom)
# - My son is suffering from [shoulder ache or pain](symptom), [flank pain](symptom), and [bloody diarrhea](symptom)
# - My symptoms are [vaginal bleeding during pregnancy](symptom), [mouth ulcers](symptom), and [poisoning](symptom)
# - For the last few days I have had [neck stiffness or tightness](symptom), [stings](symptom), and [vertigo](symptom)
# - I don't feel well, I have [abdominal swelling](symptom), [hand numbness](symptom), and [low blood sugar](symptom)
# - My symptoms are [penis pain](symptom), [tooth pain](symptom), and [double vision](symptom)
# - I don't feel well, I have [muscle pain](symptom), [weight loss, unexplained](symptom), and [hot skin](symptom)
# - My wife is suffering from [hip pain](symptom), [leg numbness](symptom), and [jaw pain](symptom)
# - My wife is suffering from [leg cut](symptom), [limping in a child](symptom), and [unsteady gait](symptom)
# - I have really bad [dark stools](symptom), [skin itching](symptom), and [hand cut](symptom)
# - My daughter is suffering from [vaginal discharge](symptom), [wrist swelling](symptom), and [arm ache or pain](symptom)
# - My symptoms are [drooling](symptom), [foot cut](symptom), and [general weakness](symptom)
# - For the last few days I have had [learning difficulties](symptom), [poisoning](symptom), and [rash](symptom)
# - I have [pelvic pain](symptom), [heart murmur](symptom), and [ingestion](symptom)
# - I'm suffering from [vertigo](symptom), [hand cut](symptom), and [rectal pain](symptom)
# - My wife is suffering from [foot swelling](symptom), [lower abdominal pain](symptom), and [double vision](symptom)
# - My son is suffering from [bleeding gums](symptom), [knee pain](symptom), and [increased facial hair](symptom)
# - I have really bad [speech problem](symptom), [loss of balance](symptom), and [eye redness](symptom)
# - My wife is suffering from [chest pressure](symptom), [general weakness](symptom), and [amenorrhea](symptom)
# - For the last few days I have had [sweating](symptom), [joint stiffness](symptom), and [night sweats](symptom)
# - I have [facial droop](symptom), [congestion in chest or lungs](symptom), and [scrotal pain](symptom)
# - My husband is suffering from [frequent urination](symptom), [swelling of both legs](symptom), and [penile discharge](symptom)
# - My wife is suffering from [puncture wound](symptom), [ear swelling](symptom), and [swallowing problem](symptom)
# - My son is suffering from [bleeding gums](symptom), [hand itching](symptom), and [snake bite](symptom)
# - My husband is suffering from [foot pain](symptom), [lump or mass of breast](symptom), and [arm ache or pain](symptom)
# - For the last few days I have had [snoring](symptom), [jaw pain](symptom), and [poisoning](symptom)
# - I have [penis pain](symptom), [toe pain](symptom), and [eye redness](symptom)
# - My symptoms are [drooping eyelid](symptom), [fever in the returning traveler](symptom), and [hurts to breathe](symptom)
# - My daughter is suffering from [shoulder stiffness or tightness](symptom), [ear swelling](symptom), and [mouth ulcers](symptom)
# - I have really bad [hand itching](symptom), [fever in the returning traveler](symptom), and [foot redness](symptom)
# - I'm suffering from [weight loss, unexplained](symptom), [groin pain](symptom), and [weight loss, unexplained](symptom)
# - My wife is suffering from [wheezing](symptom), [groin pain](symptom), and [cough](symptom)
# - My daughter is suffering from [heat illness](symptom), [itchy rash](symptom), and [behavioral problem](symptom)
# - My daughter is suffering from [eye pain](symptom), [mouth pain](symptom), and [abscess](symptom)
# - For the last few days I have had [facial pain](symptom), [constipation](symptom), and [calf pain](symptom)
# - My son is suffering from [increased urination](symptom), [vomiting](symptom), and [low heart rate](symptom)
# - My wife is suffering from [nasal injury](symptom), [leg numbness](symptom), and [skin bumps](symptom)
# - I'm suffering from [anxiety](symptom), [numbness](symptom), and [face numbness](symptom)
# - I have [headache](symptom), [nausea](symptom), and [groin pain](symptom)
# - My symptoms are [limping in a child](symptom), [heat illness](symptom), and [headache and weakness](symptom)
# - My husband is suffering from [swallowing problem](symptom), [eye floaters](symptom), and [stomach and abdominal pain](symptom)
# - My wife is suffering from [frequent urination](symptom), [joint stiffness](symptom), and [urinary retention](symptom)
# - For the last few days I have had [weight loss, unexplained](symptom), [eye redness](symptom), and [hypothermia](symptom)
# - My daughter is suffering from [lip swelling](symptom), [increased thirst](symptom), and [weight loss, unexplained](symptom)
# - For the last few days I have had [foot pain](symptom), [heat illness](symptom), and [alcohol abuse](symptom)
# - My daughter is suffering from [upper leg pain](symptom), [pustule](symptom), and [leg numbness](symptom)
# - My symptoms are [rectal pain](symptom), [rectal pain](symptom), and [elbow ache or pain](symptom)
# - My child is suffering from [psychiatric problem](symptom), [eye redness](symptom), and [excessive appetite](symptom)
# - My son is suffering from [visual problems](symptom), [nail injury](symptom), and [vaginal discharge](symptom)
# - I have really bad [snake bite](symptom), [unsteady gait](symptom), and [lump or mass of breast](symptom)
# - I don't feel well, I have [nasal injury](symptom), [unusual color or odor of urine](symptom), and [bloody diarrhea](symptom)
# - For the last few days I have had [skin swelling](symptom), [tooth pain](symptom), and [calf swelling](symptom)
# - My child is suffering from [rectal swelling](symptom), [lower abdominal pain](symptom), and [hair loss](symptom)
# - For the last few days I have had [hemoptysis](symptom), [low heart rate](symptom), and [penis inflammation or swelling](symptom)
# - My husband is suffering from [skin sores](symptom), [tooth pain](symptom), and [heart murmur](symptom)
# - My child is suffering from [traveler's diarrhea](symptom), [dizziness](symptom), and [leg itching](symptom)
# - I have really bad [darkening of the skin](symptom), [nasal injury](symptom), and [lower abdominal pain](symptom)
# - I'm suffering from [scrotal swelling](symptom), [eye floaters](symptom), and [jaundice](symptom)
# - I'm suffering from [hand numbness](symptom), [mouth ulcers](symptom), and [eye pain](symptom)
# - My wife is suffering from [rectal swelling](symptom), [ear swelling](symptom), and [flatulence](symptom)
# - My child is suffering from [fever in the returning traveler](symptom), [visual problems](symptom), and [anger](symptom)
# - I have [foot itching](symptom), [steatorrhea](symptom), and [penis inflammation or swelling](symptom)
# - My husband is suffering from [leg redness](symptom), [painful rash](symptom), and [blister](symptom)
# - For the last few days I have had [traveler's diarrhea](symptom), [poisoning](symptom), and [sleep disorders](symptom)
# - My husband is suffering from [chest burning](symptom), [swelling](symptom), and [cough](symptom)
# - I don't feel well, I have [skin swelling](symptom), [skin pain](symptom), and [heart pulsations and palpitations](symptom)
# - I have really bad [incontinence](symptom), [joint pain](symptom), and [toe pain](symptom)
# - I'm suffering from [rectal swelling](symptom), [behavioral problem](symptom), and [wrist pain](symptom)
# - My child is suffering from [visual problems](symptom), [tooth pain](symptom), and [fever of unknown origin](symptom)
# - My wife is suffering from [stings](symptom), [bleeding tendency](symptom), and [speech problem](symptom)
# - I don't feel well, I have [skin itching](symptom), [suicidal tendencies](symptom), and [low blood sugar](symptom)
# - My wife is suffering from [choking](symptom), [dark stools](symptom), and [ear swelling](symptom)
# - My wife is suffering from [visual problems](symptom), [dizziness](symptom), and [puncture wound](symptom)
# - I'm suffering from [fever of unknown origin](symptom), [learning difficulties](symptom), and [leg redness](symptom)
# - I don't feel well, I have [wrist swelling](symptom), [insomnia](symptom), and [tooth pain](symptom)
# - My child is suffering from [amenorrhea](symptom), [lethargy](symptom), and [arm stiffness or tightness](symptom)
# - I have really bad [leg numbness](symptom), [foot cut](symptom), and [scrotal swelling](symptom)
# - I have [headache after trauma](symptom), [hypothermia](symptom), and [swallowing problem](symptom)
# - My daughter is suffering from [headache](symptom), [poisoning](symptom), and [nasal congestion](symptom)
# - My son is suffering from [anxiety](symptom), [arm numbness](symptom), and [hand numbness](symptom)
# - My son is suffering from [pregnancy problem](symptom), [visual flashing lights](symptom), and [unusual color or odor of urine](symptom)
# - I'm suffering from [jaundice](symptom), [sinus pain and pressure](symptom), and [nasal congestion](symptom)
# - My wife is suffering from [wrist pain](symptom), [skin swelling](symptom), and [double vision](symptom)
# - My daughter is suffering from [head injury](symptom), [foot pain](symptom), and [calf pain](symptom)
# - I have really bad [discharge from ear](symptom), [throat pain](symptom), and [blister](symptom)
# - My daughter is suffering from [tooth pain](symptom), [swelling](symptom), [puncture wound](symptom), [hot flashes](symptom)
# - I'm suffering from [snoring](symptom), [shortness of breath](symptom), [pain in the ear](symptom), [kidney pain](symptom)
# - My child is suffering from [weight loss, unexplained](symptom), [foot redness](symptom), [head injury](symptom), [eye redness](symptom)
# - For the last few days I have had [spider bite](symptom), [pelvic pain](symptom), [behavioral problem](symptom), [agitated](symptom)
# - For the last few days I have had [blister](symptom), [jaundice](symptom), [pulling at ears](symptom), [headache](symptom)
# - My child is suffering from [overdose](symptom), [shoulder stiffness or tightness](symptom), [learning difficulties](symptom), [heel pain](symptom)
# - For the last few days I have had [tired](symptom), [skin itching](symptom), [back ache or pain](symptom), [foot cut](symptom)
# - My son is suffering from [mouth ulcers](symptom), [skin itching](symptom), [shoulder ache or pain](symptom), [tooth pain](symptom)
# - My husband is suffering from [painful gums](symptom), [foot numbness](symptom), [flank pain](symptom), [rectal swelling](symptom)
# - I have [increased facial hair](symptom), [swollen gums](symptom), [arm cut](symptom), [night sweats](symptom)
# - I have [ear pressure](symptom), [agitated](symptom), [obesity](symptom), [difficulty breathing](symptom)
# - My symptoms are [infertility](symptom), [pregnancy problem](symptom), [high blood pressure](symptom), [trauma](symptom)
# - For the last few days I have had [behavioral problem](symptom), [itchy rash](symptom), [skin growths](symptom), [vaginal bleeding during pregnancy](symptom)
# - I have really bad [mouth pain](symptom), [retaining fluid](symptom), [swollen gums](symptom), [inconsolable baby](symptom)
# - My daughter is suffering from [scrotal swelling](symptom), [snoring](symptom), [muscle spasm](symptom), [trauma](symptom)
# - My daughter is suffering from [mouth pain](symptom), [eye floaters](symptom), [chest burning](symptom), [lower abdominal pain](symptom)
# - I have [discharge from ear](symptom), [foot redness](symptom), [vaginal bleeding during pregnancy](symptom), [elbow ache or pain](symptom)
# - I'm suffering from [tired](symptom), [hip pain](symptom), [inconsolable baby](symptom), [vaginal bleeding](symptom)
# - My wife is suffering from [pulling at ears](symptom), [foot swelling](symptom), [fever in the returning traveler](symptom), [impotence](symptom)
# - My wife is suffering from [alcohol abuse](symptom), [tooth pain](symptom), [diarrhea](symptom), [urinary retention](symptom)
# - My symptoms are [muscle spasm](symptom), [leg ache or pain](symptom), [vaginal pain](symptom), [shoulder ache or pain](symptom)
# - I have [puncture wound](symptom), [pain or soreness of breast](symptom), [swallowing problem](symptom), [foot numbness](symptom)
# - My son is suffering from [leg cut](symptom), [blood in vomit](symptom), [foot swelling](symptom), [cyanosis](symptom)
# - I have [speech problem](symptom), [calf pain](symptom), [steatorrhea](symptom), [hemoptysis](symptom)
# - My daughter is suffering from [increased thirst](symptom), [poisoning](symptom), [skin sores](symptom), [pregnancy problem](symptom)
# - I have really bad [incontinence](symptom), [upper abdominal pain](symptom), [leg itching](symptom), [swelling](symptom)
# - I have [visual flashing lights](symptom), [puncture wound](symptom), [muscle pain](symptom), [eye redness](symptom)
# - My child is suffering from [swallowing problem](symptom), [learning difficulties](symptom), [lip swelling](symptom), [chest burning](symptom)
# - I'm suffering from [elbow swelling](symptom), [pain in the ear](symptom), [cough](symptom), [eye swelling](symptom)
# - I have [hand itching](symptom), [eye floaters](symptom), [bleeding gums](symptom), [skin itching](symptom)
# - My child is suffering from [night sweats](symptom), [itchy eyes](symptom), [wrist swelling](symptom), [memory loss](symptom)
# - My daughter is suffering from [choking](symptom), [tooth pain](symptom), [swollen lymph nodes](symptom), [increased urination](symptom)
# - My symptoms are [dry skin](symptom), [diarrhea](symptom), [sleep disorders](symptom), [unusual color or odor of urine](symptom)
# - My symptoms are [arm itching](symptom), [trauma](symptom), [shoulder stiffness or tightness](symptom), [upper leg pain](symptom)
# - For the last few days I have had [leg ache or pain](symptom), [rash](symptom), [infertility](symptom), [foot numbness](symptom)
# - My husband is suffering from [pain or soreness of breast](symptom), [vaginal itching](symptom), [insect sting](symptom), [wrist swelling](symptom)
# - I don't feel well, I have [tooth pain](symptom), [knee pain](symptom), [confusion](symptom), [difficulty breathing](symptom)
# - I'm suffering from [frequent urination](symptom), [drooling](symptom), [unsteady gait](symptom), [obesity](symptom)
# - My child is suffering from [impotence](symptom), [rash](symptom), [throat pain](symptom), [sweating](symptom)
# - I have [upper abdominal pain](symptom), [weakness](symptom), [stomach and abdominal pain](symptom), [throat pain](symptom)
# - For the last few days I have had [painful urination](symptom), [jaw pain](symptom), [itchy rash](symptom), [nasal injury](symptom)
# - My husband is suffering from [foot numbness](symptom), [incontinence](symptom), [cyanosis](symptom), [insomnia](symptom)
# - My son is suffering from [neck swelling](symptom), [speech problem](symptom), [calf pain](symptom), [bleeding in brain](symptom)
# - My child is suffering from [frequent urination](symptom), [elbow ache or pain](symptom), [confusion and headache](symptom), [skin growths](symptom)
# - My child is suffering from [fainting](symptom), [armpit pain](symptom), [ingestion](symptom), [overdose](symptom)
# - My wife is suffering from [hot flashes](symptom), [rectal pain](symptom), [frequent urination](symptom), [muscle pain](symptom)
# - My daughter is suffering from [vaginal bleeding](symptom), [nasal injury](symptom), [flank pain](symptom), [anxiety](symptom)
# - For the last few days I have had [jaw pain](symptom), [blurry vision](symptom), [nausea](symptom), [high blood sugar](symptom)
# - I have really bad [facial pain](symptom), [hot flashes](symptom), [leg redness](symptom), [blood in urine](symptom)
# - I don't feel well, I have [vaginal bleeding during pregnancy](symptom), [neck ache or pain](symptom), [increased thirst](symptom), [vomiting coffee ground material](symptom)
# - My son is suffering from [loss of balance](symptom), [vaginal itching](symptom), [nausea](symptom), [chest burning](symptom)
# - My son is suffering from [knee pain](symptom), [liver failure](symptom), [vomiting](symptom), [wheezing](symptom)
# - I don't feel well, I have [tongue swelling](symptom), [hemoptysis](symptom), [behavioral problem](symptom), [hand itching](symptom)
# - I'm suffering from [penis inflammation or swelling](symptom), [memory loss](symptom), [loss of balance](symptom), [ear swelling](symptom)
# - I have [seizure](symptom), [arm itching](symptom), [bloody diarrhea](symptom), [ingestion](symptom)
# - I'm suffering from [high blood pressure](symptom), [leg numbness](symptom), [stings](symptom), [unusual color or odor of urine](symptom)
# - My symptoms are [anger](symptom), [obesity](symptom), [dizziness](symptom), [delusions or hallucinations](symptom)
# - I have [eye floaters](symptom), [trauma](symptom), [foot swelling](symptom), [overdose](symptom)
# - For the last few days I have had [inconsolable baby](symptom), [hot skin](symptom), [hand redness](symptom), [night sweats](symptom)
# - I don't feel well, I have [penile discharge](symptom), [low blood pressure](symptom), [ringing in ears](symptom), [scrotal swelling](symptom)
# - I don't feel well, I have [snoring](symptom), [retaining fluid](symptom), [nipple discharge](symptom), [muscle spasm](symptom)
# - My husband is suffering from [shortness of breath](symptom), [ringing in ears](symptom), [shortness of breath](symptom), [increased facial hair](symptom)
# - My daughter is suffering from [chest burning](symptom), [bleeding in brain](symptom), [frequent urination](symptom), [painful urination](symptom)
# - I have [diarrhea](symptom), [drooling](symptom), [diarrhea](symptom), [heat illness](symptom)
# - I'm suffering from [vaginal itching](symptom), [difficulty breathing](symptom), [kidney pain](symptom), [inconsolable baby](symptom)
# - My husband is suffering from [vaginal pain](symptom), [tooth pain](symptom), [hand redness](symptom), [heel pain](symptom)
# - My wife is suffering from [arm numbness](symptom), [upper abdominal pain](symptom), [mouth ulcers](symptom), [maroon stools](symptom)
# - My child is suffering from [sinus pain and pressure](symptom), [eye redness](symptom), [ingestion](symptom), [insect sting](symptom)
# - My symptoms are [ingestion](symptom), [alcohol abuse](symptom), [leg cut](symptom), [skin trauma](symptom)
# - I have [head injury](symptom), [hair loss](symptom), [fainting](symptom), [steatorrhea](symptom)
# - My son is suffering from [mouth swelling](symptom), [skin pain](symptom), [change in behavior](symptom), [foot pain](symptom)
# - My child is suffering from [heart murmur](symptom), [chills](symptom), [upper abdominal pain](symptom), [shin pain](symptom)
# - I'm suffering from [flank pain](symptom), [bloody diarrhea](symptom), [wrist swelling](symptom), [swelling of both legs](symptom)
# - My wife is suffering from [puncture wound](symptom), [melena](symptom), [flatulence](symptom), [visual flashing lights](symptom)
# - I have [snake bite](symptom), [hemoptysis](symptom), [jaundice](symptom), [vertigo](symptom)
# - My husband is suffering from [skin swelling](symptom), [hemoptysis](symptom), [calf pain](symptom), [foot cut](symptom)
# - My son is suffering from [pain or soreness of breast](symptom), [limping in a child](symptom), [back ache or pain](symptom), [joint pain](symptom)
# - My son is suffering from [liver failure](symptom), [ankle pain](symptom), [leg cut](symptom), [sweating](symptom)
# - I don't feel well, I have [cranky, crying, fussy, irritable child](symptom), [increased thirst](symptom), [elbow ache or pain](symptom), [drooping eyelid](symptom)
# - My daughter is suffering from [mouth ulcers](symptom), [sneezing](symptom), [inconsolable baby](symptom), [sore throat](symptom)
# - I'm suffering from [chest pressure](symptom), [insect sting](symptom), [kidney pain](symptom), [hemoptysis](symptom)
# - My child is suffering from [painful gums](symptom), [skin infection](symptom), [knee pain](symptom), [choking](symptom)
# - I have [learning difficulties](symptom), [bleeding gums](symptom), [stings](symptom), [arm numbness](symptom)
# - I have really bad [arm swelling](symptom), [groin pain](symptom), [insomnia](symptom), [hand cut](symptom)
# - My husband is suffering from [high blood pressure](symptom), [inconsolable baby](symptom), [nasal injury](symptom), [trauma](symptom)
# - My daughter is suffering from [rash](symptom), [scrotal pain](symptom), [choking](symptom), [blood in vomit](symptom)
# - I have really bad [melena](symptom), [ringing in ears](symptom), [eye swelling](symptom), [increased facial hair](symptom)
# - My daughter is suffering from [low blood pressure](symptom), [knee pain](symptom), [mouth swelling](symptom), [pain in the ear](symptom)
# - I have [melena](symptom), [ingestion](symptom), [hair loss](symptom), [arm redness](symptom)
# - My son is suffering from [discharge from ear](symptom), [low blood pressure](symptom), [impotence](symptom), [learning difficulties](symptom)
# - I don't feel well, I have [frequent urination](symptom), [hand, finger ache or pain](symptom), [increased urination](symptom), [leg numbness](symptom)
# - I have really bad [shortness of breath](symptom), [ingestion](symptom), [psychiatric problem](symptom), [eye redness](symptom)
# - I'm suffering from [ingestion](symptom), [bleeding tendency](symptom), [agitated](symptom), [impotence](symptom)
# - I'm suffering from [seizure](symptom), [rectal pain](symptom), [pulling at ears](symptom), [inconsolable baby](symptom)
# - My daughter is suffering from [shoulder ache or pain](symptom), [visual problems](symptom), [limping in a child](symptom), [low blood sugar](symptom)
# - My wife is suffering from [increased facial hair](symptom), [numbness](symptom), [skin infection](symptom), [arm itching](symptom)
# - For the last few days I have had [weight loss, unexplained](symptom), [sneezing](symptom), [swelling](symptom), [foot swelling](symptom)
# - For the last few days I have had [wrist pain](symptom), [dry skin](symptom), [flatulence](symptom), [speech problem](symptom)
# - My wife is suffering from [vertigo](symptom), [arm redness](symptom), [failure to thrive](symptom), [hemoptysis](symptom)
# - My child is suffering from [drooling](symptom), [suicidal tendencies](symptom), [sneezing](symptom), [snake bite](symptom)
